# %% [markdown]
# # Giai doan 1: Khao sat va chuan bi du lieu (EDA)
#
# Khao sat 2 bo du lieu: Brazilian Insurance Market Data (SUSEP) va Prudential Life Insurance Assessment.

# %% [markdown]
# ## 1. Load data

# %%
# TODO: Load dataset SUSEP va Prudential vao pandas DataFrame
# import pandas as pd
# df_susep = pd.read_csv('../data/raw/...')
# df_prudential = pd.read_csv('../data/raw/...')

# %% [markdown]
# ## 2. Shape & dtypes

# %%
# TODO: Kiem tra so dong, so cot va kieu du lieu
# print(df_susep.shape, df_susep.dtypes)
# print(df_prudential.shape, df_prudential.dtypes)

# %% [markdown]
# ## 3. Null check

# %%
# TODO: Thong ke ty le missing/null values tren tung cot

# %% [markdown]
# ## 4. Duplicate check

# %%
# TODO: Kiem tra cac ban ghi trung lap (duplicate rows/keys)

# %% [markdown]
# ## 5. Data quality issues found

# %%
# TODO: Tong hop danh sach cac van de ve chat luong du lieu (encoding, format ngay thang, BRL currency, category encoding)
